# %%
# Import relevant libraries
import pandas as pd
import spacy
from collections import Counter
from tqdm.notebook import tqdm

# %%
# Load train dataset into dataframe
df_train = pd.read_csv('train.csv')

# %%
# Setup spaCy language model. The large language model was chosen to ensure maximum number of words were tokenised
nlp = spacy.load("en_core_web_lg")

# %%
# Adding lemmas of the word to reduce complexity of the data
# Additionally, stopwords were excluded and only alphabetical words were included
docs_train = [[tkn.lemma_.lower() for tkn in nlp(doc) if (not tkn.is_stop) & (tkn.is_alpha)] for doc in tqdm(df_train.text)]
# Out:
#   0%|          | 0/21057 [00:00<?, ?it/s]

# %%
# Inserting the tokens into a separate dataframe
df_train_1 = df_train
df_train_1['Tokens'] = docs_train
df_train_1.head()
# Out:
#    label                                               text  \
# 0      0  Batch #5\n\nAppearance: Pours a slightly hazy ...
# 1      0  Murky peach color with off-white head. Aroma h...
# 2      0  Can poured into a Spiegelau IPA glass\n\nA: Po...
# 3      0  A big thanks to Jeff for this one. 750ml cappe...
# 4      0  On tap into a shaker pint.\n\nAppearance is go...
#
#                                               Tokens
# 0  [batch, appearance, pour, slightly, hazy, aubu...
# 1  [murky, peach, color, white, head, aroma, tart...
# 2  [pour, spiegelau, ipa, glass, pour, golden, am...
# 3  [big, thank, jeff, cap, bottle, brooklyn, brew...
# 4  [tap, shaker, pint, appearance, golden, amber,...

# %%
# Collect the total list of words into train_list
train_list = []
for lst in df_train_1['Tokens']:
    for tkn in lst:
        train_list.append(tkn)

# Count the frequency of the words across the entire corpus
train_count = Counter(train_list)
print(train_count)

# Find words to exclude from the corpus. Words occurrring more than 7730 times and fewer than or equal to 5 times were removed
# This was done to ensure that the approaches used to classify the reviews would only use the most relevant words
words_to_exclude = []
for word, count in train_count.items():
    if (count <= 5) or (count > 7730):
        words_to_exclude.append(word)

# A peek into the words being excluded
print(words_to_exclude)
print(len(words_to_exclude))
# Out:
# Counter({'beer': 24280, 'head': 16955, 'hop': 15832, 'taste': 15154, 'malt': 14262, 'pour': 13016, 'flavor': 12955, 'good': 12940, 'nice': 12527, 'light': 11858, 'like': 11183, 'sweet': 10043, 'dark': 10041, 'aroma': 9374, 'finish': 9110, 'smell': 9102, 'carbonation': 8721, 'bit': 7727, 'note': 7436, 'medium': 7379, 'glass': 7123, 'bottle': 7052, 'chocolate': 7006, 'color': 6787, 'body': 6753, 'fruit': 6746, 'white': 6621, 'little': 6581, 'brown': 6055, 'great': 6004, 'mouthfeel': 5924, 'citrus': 5639, 'caramel': 5528, 'nose': 5497, 'smooth': 5426, 'coffee': 5380, 'orange': 5355, 'lacing': 5297, 'alcohol': 5199, 'bitterness': 5098, 'dry': 4990, 'overall': 4868, 'hint': 4716, 'drink': 4696, 'bitter': 4667, 'sweetness': 4465, 'brew': 4307, 'leave': 4268, 'creamy': 4171, 'ipa': 4044, 'black': 4030, 'lot': 3995, 'come': 3975, 'feel': 3925, 'thick': 3896, 'finger': 3782, 'slightly': 3768, 'big': 3753, 's': 3681, 'style': 3600, 'ale': 3584, 't': 3556, 'vanilla': 3440, 'pretty': 3438, 'strong': 3436, 'look': 3398, 'roasted': 3312, 'slight': 3283,
docent', 'playboy', 'nickle', 'aite', 'rotted', 'envision', 'toastedness', 'blandness', 'atomic', 'deere', 'fluffly', 'vastly', 'tallgrass', 'stony', 'horehound', 'gulf', 'nutbrown', 'der', 'alte', 'ist', 'roatstiness', 'birkinau', 'bourne', 'nite', 'tantalize', 'cinnsanity', 'fpbc', 'dextrose', 'snca', 'piddly', 'shrank', 'span', 'ardmore', 'lemonx', 'craftsman', 'harrison', 'moderatly', 'versitility', 'sioux', 'headless', 'merriment', 'propel', 'refrese', 'clemente', 'jagged', 'spotting', 'unorthodox', 'salvation', 'sensible', 'seeing', 'demensional', 'cancel', 'figs', 'skyroc', 'eqsque', 'recollection', 'bcaa', 'fst', 'puzzle', 'eggplant', 'cachaca', 'goop', 'aubrey', 'creepy', 'elementary', 'overexcited', 'brazilian', 'jmbh', 'vigorously', 'deprive', 'brewbaker', 'wasp', 'jacob', 'puttin', 'sledgehammer', 'firemans', 'thou', 'ligher', 'ow', 'oranges', 'peasant', 'riversidepark', 'froal', 'withfairly', 'drinkble', 'deisired', 'cumberland', 'gracious', 'heartburn', 'stockholm', 'cooperative', 'spendrups', 'wc', 'leafer', 'apas', 'sudue', 'semisweetness', 'everlasting', 'continur', 'awyeh', 'radically', 'splitting', 'beneficial', 'diminshe', 'hopbitterness', 'mouthsticky', 'mouthfeeling', 'maibocks', 'flavorless', 'yakima', 'iceberg', 'artistic', 'sculpt', 'storng', 'rebuttal', 'waltz', 'terse', 'peels', 'govern', 'dialogue', 'supplant', 'interrupt', 'icicle', 'nearl', 'hump', 'begyle', 'shatter', 'americo', 'tons', 'beaming', 'lustrously', 'protrude', 'mural', 'abstract', 'characteristically ...
# 19335

# %%
# List of words excluding the words obtained at the previous step
docs_train_2 = [[tkn for tkn in doc if (not tkn in words_to_exclude)] for doc in tqdm(df_train.Tokens)]
# Out:
#   0%|          | 0/21057 [00:00<?, ?it/s]

# %%
# Creating a new dataframe to export the results into
# The column token string was added due to problems faced when importing the csv file
df_train_3 = df_train
df_train_3['Tokens'] = docs_train_2
df_train_3['Token string'] = df_train_3['Tokens'].apply(lambda tkn: " ".join(tkn))
df_train_3.head()
# Out:
#    label                                               text  \
# 0      0  Batch #5\n\nAppearance: Pours a slightly hazy ...
# 1      0  Murky peach color with off-white head. Aroma h...
# 2      0  Can poured into a Spiegelau IPA glass\n\nA: Po...
# 3      0  A big thanks to Jeff for this one. 750ml cappe...
# 4      0  On tap into a shaker pint.\n\nAppearance is go...
#
#                                               Tokens  \
# 0  [batch, appearance, slightly, hazy, auburn, co...
# 1  [murky, peach, color, white, tart, fruit, kind...
# 2  [spiegelau, ipa, glass, golden, amber, kinda, ...
# 3  [big, thank, jeff, cap, bottle, brooklyn, brew...
# 4  [tap, shaker, pint, appearance, golden, amber,...
#
#                                         Token string
# 0  batch appearance slightly hazy auburn color fi...
# 1  murky peach color white tart fruit kind minera...
# 2  spiegelau ipa glass golden amber kinda creamy ...
# 3  big thank jeff cap bottle brooklyn brewery sni...
# 4  tap shaker pint appearance golden amber lot la...

# %%
# Write to a csv file
df_train_3.to_csv('train_processed.csv', index=False)
